# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy as sci
from scipy.stats import norm
import itertools
from matplotlib import cm

# %%
#Creates empty list for x, y, z, and energy value of hits
xlist = []
ylist = []
zlist = []
elist = []
lastx = []
lasty = []
lastz = []

# %%
#Creates function to remove extra spaces in sim file
def cleanlines(line):
    remove = ['  ', ' ']
    for r in remove:
        clean = line.replace(r, '') 
    split = clean.split(';')
    return split

# %%
#Starts tallies in detector at 0
counts = 0
data = open('Stripped_Dir_Test.sim', 'r')
for l in data:
    line = cleanlines(l.strip('\n'))
    if line[0][2:6] == 'BLAK' and line[1] == '1':  #len(line) >= 1 and
        counts +=1
        elist.append(np.float32(line[14]))
        xlist.append(np.float32(line[4]))
        ylist.append(np.float32(line[5]))
        zlist.append(np.float32(line[6]))
        line2 = cleanlines(next(data).strip('\n'))
        lastx.append(np.float32(line2[4]))
        lasty.append(np.float32(line2[5]))
        lastz.append(np.float32(line2[6]))  
data.close()

# %%
print(counts)
# Out:
# 555271

# %%
#Converting to cylindrical coordinates (r,phi,z)
#Generates phi -180 to 180 degrees
phi = np.arctan2(ylist,xlist)*180/np.pi

# %%
Tot = np.array(list(zip(xlist,ylist,zlist,elist,lastx,lasty,lastz,phi)))
print(Tot.shape)
# Out:
# (555271, 8)

# %%
#Confirms constant r of 750 cm for all datapoints 
r = np.sqrt(Tot[:,0]**2+Tot[:,1]**2)
print(r)
# Out:
# [750.      750.      750.      ... 749.99994 750.      750.     ]

# %%
xedges = np.arange(-180.0, 180.1, 3.)
yedges = np.arange(0., 1000.1, 40.)
heatmap1, _, __ = np.histogram2d(Tot[:,7],Tot[:,2], bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(18,4))
im1 = plt.imshow(heatmap1.T, extent=extent, aspect='auto', origin='lower')
plt.xticks(np.arange(-180., 181., 30.))
#plt.ylim(480, 520)
cb = plt.colorbar(im1)
cb.set_label('Hits')
plt.title('Total Detector Response = ' + str(len(Tot)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
#plt.savefig('images/1Total_.png')
plt.show()

# %%
flip1 = np.transpose(heatmap1)

# %%
# Fit a normal distribution to the data:
mu, std = norm.fit(flip1[13])
# Plot the histogram.
plt.hist(flip1[13], bins=12, density=True, alpha=0.6, color='g')
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: Mean = %.2f,  St. Dev. = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
A = 1000000 #Activity 1 mil particles
R = 750 # Distance to detector cm
h = 40 # Height of detector cm
Area = 2*np.pi*R*h/120 # Area of detector cm^2
CR = A*Area/(4*np.pi*R**2) #counts
print(CR)
# Out:
# 222.22222222222223

# %%
Tot_Err = [165.76, 138.86, 394.93, 134.64, 36.30, 316.12, 89.33, 36.14, 361.73]
# Fit a normal distribution to the data:
mu, std = norm.fit(Tot_Err)
# Plot the histogram.
plt.hist(Tot_Err, bins=6, density=True, alpha=0.6, color='g')
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Total: Mean = %.2f,  St. Dev. = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
Full_Err = [92.95, 54.52, 30.22, 101.34, 79.29, 7.43, 37.25, 23.86, 36.40]
# Fit a normal distribution to the data:
mu, std = norm.fit(Full_Err)
# Plot the histogram.
plt.hist(Full_Err, bins=6, density=True, alpha=0.6, color='g')
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Full: Mean = %.2f,  St. Dev. = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
Part_Err = [173.09, 100.95, 354.67, 149.89, 48.54, 51.54, 99.52, 36.91, 385.27]
# Fit a normal distribution to the data:
mu, std = norm.fit(Part_Err)
# Plot the histogram.
plt.hist(Part_Err, bins=6, density=True, alpha=0.6, color='g')
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Part: Mean = %.2f,  St. Dev. = %.2f" % (mu, std)
plt.title(title)
plt.show()
