# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def cleanlines(line):
    remove = ['  ', ' ']
#     if len(line) <= 10:
#         null = 'NULL'
#         return null 
    for r in remove:
        clean = line.replace(r, '') 
    split = clean.split(';')
    return split

# %%
data = open('direct.inc1.id1.sim', 'r').read()
lines = data.split('\n')

# %%
darrell_arr = np.dtype({"names": ['x_value', 'y_value','z_value'], "formats": [np.float32, np.float32, np.float32]})
xlist = []
ylist = []
zlist = []
c = 0
for l in lines:
    line  = cleanlines(l)
    #print(line[0][2:6])
    if len(line) > 1 and line[0][2:6] == 'BLAK':
        #print(line)
        c +=1
        xlist.append(np.float32(line[4]))
        ylist.append(np.float32(line[5]))
        zlist.append(np.float32(line[6]))
print(c)
        

useful_arr = np.zeros(len(xlist), darrell_arr)
useful_arr['x_value'] = xlist
useful_arr['y_value'] = ylist
useful_arr['z_value'] = zlist
useful_arr[:100]
# Out:
# 369
# array([( 502.82000732, -346.37240601, -17.25317001),
#        ( 502.82000732, -306.41409302,  11.6697197 ),
#        ( 502.82000732, -318.28433228,  28.95195007),
#        ( 502.82000732, -331.5899353 , -18.15505981),
#        ( 502.82000732, -338.35571289,  10.03635979),
#        ( 502.82000732, -317.69665527, -19.72723007),
#        ( 502.82000732, -348.6060791 , -15.79792023),
#        ( 502.82000732, -355.16650391,  10.84393024),
#        ( 502.82000732, -349.74685669, -16.69820023),
#        ( 502.82000732, -351.55712891,  13.46916008),
#        ( 502.82000732, -341.9085083 ,   8.42226982),
#        ( 502.82000732, -345.75735474, -15.88197041),
#        ( 502.82000732, -348.31542969,  14.79695988),
#        ( 502.82000732, -310.90133667, -25.88973045),
#        ( 502.82000732, -343.26889038,  -7.05320978),
#        ( 502.82000732, -345.43850708,  11.84228039),
#        ( 502.82000732, -333.31906128, -29.67721939),
#        ( 502.82000732, -304.81185913,   5.63262987),
#        ( 502.82000732, -317.64559937, -14.2329998 ),
#        ( 502.82000732, -348.82678223,  17.49523926),
#        ( 502.82000732, -360.4750061 ,   7.42683983),
#        ( 502.82000732, -361.61660767,  25.17532921),
#        ( 502.82000732, -347.24810791,  -2.87926006),
#        ( 502.82000732, -305.62338257,   6.01319981),
#        ( 502.82000732, -334.08514404,  18.88262939),
#        ( 502.82000732, -348.91964722,   9.0720396 ),
#        ( 502.82000732, -340.8119812 ,  12.73204041),
#        ( 502.82000732, -323.34875488,   6.92940998),
#        ( 502.82000732, -357.39212036,  18.33135033),
#        ( 502.82000732, -310.84985352,  27.95321083),
#        ( 502.82000732, -327.06445312, -21.9841404 ),
#        ( 502.82000732, -322.49194336, -20.38293076),
#        ( 502.82000732, -334.18902588,   3.84429002),
#        ( 502.82000732, -307.08874512,  11.96827984),
#        ( 502.82000732, -307.77484131, -29.87396049),
#        ( 502.82000732, -327.74502563, -16.37071991),
#        ( 502.82000732, -311.40020752, -23.79504013),
#        ( 502.82000732, -323.71743774,  29.49802971),
#        ( 502.82000732, -341.89517212,  25.31204033),
#        ( 502.82000732, -358.27313232, -18.48611069),
#        ( 502.82000732, -314.28033447,  -1.57258999),
#        ( 502.82000732, -343.47283936,  29.10806084),
#        ( 502.82000732, -337.23251343,  29.30662918),
#        ( 502.82000732, -363.09014893,  -9.99015999),
#        ( 502.82000732, -304.88562012,  19.82690048),
#        ( 502.82000732, -349.54568481,  11.35534954),
#        ( 502.82000732, -315.99615479,  -3.36502004),
#        ( 502.82000732, -355.74951172,  -0.61443001),
#        ( 502.82000732, -340.40621948, -14.52046967),
#        ( 502.82000732, -356.01409912, -17.50087929),
#        ( 502.82000732, -342.52496338,  13.1749897 ),
#        ( 502.82000732, -329.15814209,  -5.14734983),
#        ( 502.82000732, -335.1663208 ,  26.16127014),
#        ( 502.82000732, -350.50198364, -22.88421059),
#        ( 502.82000732, -337.90432739,  -3.70699   ),
#        ( 502.82000732, -346.28607178,   9.57530022),
#        ( 502.82000732, -329.17776489,  19.79704094),
#        ( 502.82000732, -344.47625732, -19.14488983),
#        ( 502.82000732, -320.57144165,  21.46660995),
#        ( 502.82000732, -357.57241821,   9.78917027),
#        ( 502.82000732, -313.6701355 ,   8.23355007),
#        ( 502.82000732, -351.23898315, -12.01758003),
#        ( 502.82000732, -363.58529663,  -7.12952995),
#        ( 502.82000732, -348.984375  ,  14.08463955),
#        ( 502.82000732, -334.06887817,  -4.3481102 ),
#        ( 502.82000732, -310.41546631, -25.92321014),
#        ( 502.82000732, -348.32565308,  25.11977959),
#        ( 502.82000732, -309.93322754,  -4.40423012),
#        ( 502.82000732, -323.33703613, -30.41846085),
#        ( 502.82000732, -344.91812134,  -1.14687002),
#        ( 502.82000732, -329.15737915,  23.1405201 ),
#        ( 502.82000732, -350.19515991,  -8.30739021),
#        ( 502.82000732, -309.76281738,  23.91506958),
#        ( 502.82000732, -343.35995483,  27.69057083),
#        ( 502.82000732, -363.86029053,   3.4324801 ),
#        ( 502.82000732, -335.34594727,   7.03050995),
#        ( 502.82000732, -361.25      , -29.01244926),
#        ( 502.82000732, -329.30603027,   1.06957996),
#        ( 502.82000732, -346.58511353,   6.39337015),
#        ( 502.82000732, -351.81881714, -24.07591057),
#        ( 502.82000732, -330.52584839,   9.82028008),
#        ( 502.82000732, -350.67245483,  10.42757988),
#        ( 502.82000732, -330.84967041,  14.87394047),
#        ( 502.82000732, -338.41333008, -10.48091984),
#        ( 502.82000732, -338.70214844, -20.03022957),
#        ( 502.82000732, -324.5894165 , -19.5739994 ),
#        ( 502.82000732, -339.48510742,  -2.33090997),
#        ( 502.82000732, -360.34487915,   4.93828011),
#        ( 502.82000732, -309.57223511,  -9.33705997),
#        ( 502.82000732, -362.88885498, -18.20525932),
#        ( 502.82000732, -314.23202515,  10.21805954),
#        ( 502.82000732, -306.05285645,  24.11709976),
#        ( 502.82000732, -349.59036255,  28.35853958),
#        ( 502.82000732, -361.96533203,   1.28322995),
#        ( 502.82000732, -306.27407837,   1.88975   ),
#        ( 502.82000732, -337.31869507, -29.30039978),
#        ( 502.82000732, -344.58746338,   6.5469799 ),
#        ( 502.82000732, -321.5296936 ,  10.14885998),
#        ( 502.82000732, -358.37216187,   3.95916009),
#        ( 502.82000732, -357.33621216, -15.61806965)],
#       dtype=[('x_value', '<f4'), ('y_value', '<f4'), ('z_value', '<f4')])

# %%
zhist, bins = np.histogram(data, bins=24, range=(-29.21, 29.21))
yhist, bins = np.histogram(data2, bins=24, range=(-367.03, -306.07))
# Out:
# 'IA BLAK  2; 1;4;5.684217442508e-09; 502.82000;-306.41409;  11.66972;1; 0.98317; 0.16939; 0.06848; 0.00000; 0.00000; 0.00000;  1332.492;0; 0.00000; 0.00000; 0.00000; 0.00000; 0.00000; 0.00000;     0.000'

# %%
def cleanlines(line):
    remove = ['  ', ' ']
    for r in remove:
        clean = line.replace(r, '') 
    split = clean.split(';')
    print(split)

# %%
H, zedge, yedge = np.histogram2d(useful_arr['z_value'], useful_arr['y_value'], bins=[24, 24], range=[[-29.21, 29.21], [-367.03, -306.07]])

# %%
plt.plot(H)
plt.show()

# %%
a = 2.54*24

# %%
-306.07-a
# Out:
# -367.03

# %%
np.histogram2d?
