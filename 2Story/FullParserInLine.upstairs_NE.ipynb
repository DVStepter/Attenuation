# %%
import numpy as np
import matplotlib
import matplotlib.animation as animation
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools
from matplotlib import cm

# %%
plt.interactive(True)

# %%
Tot = np.load('total_up_NE.npy')

# %%
print(Tot.shape)
# Out:
# (2055117, 8)

# %%
Full = max(Tot[:,3])
FullE = Tot[Tot[:,3]==Full] #Creates array of only full energy deposition
Conc = Tot[(Tot[:,3]<Full) & (Tot[:,6]>0)] #Creates array of less than full energy deposition - Concrete Scattered
Asph = Tot[(Tot[:,3]<Full) & (Tot[:,6]<=0)] #Creates array of less than full energy deposition - Asphault Scattered
print(FullE.shape)
print(Conc.shape)
print(Asph.shape)
# Out:
# (716358, 8)
# (1263929, 8)
# (74830, 8)

# %%
#Confirms constant r of 1000 cm for all datapoints 
r = np.sqrt(Tot[:,0]**2+Tot[:,1]**2)
print(r)
# Out:
# [1000.      1000.      1000.      ... 1000.00006 1000.00006 1000.     ]

# %%
xedges = np.arange(-180.0, 180.1, 3.)
yedges = np.arange(0., 1400.1, 40.)
heatmap1, _, __ = np.histogram2d(Tot[:,7],Tot[:,2], bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(18.8496,8))
plt.imshow(heatmap1.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.xticks(np.arange(-180., 181., 30.))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Detector Response = ' + str(len(Tot)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
#plt.savefig('images/1Total_up_NE.png')
plt.show()

# %%
xedges = np.arange(-180.0, 180.1, 3.)
yedges = np.arange(0., 1400.1, 40.)
heatmap2, _, __ = np.histogram2d(FullE[:,7],FullE[:,2], bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(18.8496,8))
plt.imshow(heatmap2.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.xticks(np.arange(-180., 181., 30.))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Deposition = ' + str(len(FullE)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
#plt.savefig('images/2FullE_up_NE.png')
plt.show()

# %%
xedges = np.arange(-180.0, 180.1, 3.)
yedges = np.arange(0., 1400.1, 40.)
heatmap3, _, __ = np.histogram2d(Conc[:,7],Conc[:,2], bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(18.8496,8))
plt.imshow(heatmap3.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.xticks(np.arange(-180., 181., 30.))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Concrete Scattered = ' + str(len(Conc)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
#plt.savefig('images/3Concrete_Scatter_up_NE.png')
plt.show()

# %%
xedges = np.arange(-180.0, 180.1, 3.)
yedges = np.arange(0., 1400.1, 40.)
heatmap4, _, __ = np.histogram2d(Asph[:,7],Asph[:,2], bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(18.8496,8))
plt.imshow(heatmap4.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.xticks(np.arange(-180., 181., 30.))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Asphalt Scattered = ' + str(len(Asph)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
#plt.savefig('images/4Asphalt_Scatter_up_NE.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(18.8496,8)) 

plt.subplot(411)
plt.imshow(heatmap1.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.title('Total Detector Response = ' + str(len(Tot)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
cb = plt.colorbar()
cb.set_label('Hits')
plt.subplot(412)
plt.imshow(heatmap2.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.title('Full Energy Deposition = ' + str(len(FullE)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
cb = plt.colorbar()
cb.set_label('Hits')
plt.subplot(413)
plt.imshow(heatmap3.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.title('Concrete Scattered = ' + str(len(Conc)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
cb = plt.colorbar()
cb.set_label('Hits')
plt.subplot(414)
plt.imshow(heatmap4.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(heatmap1))
plt.title('Asphalt Scattered = ' + str(len(Asph)) +' hits')
plt.xlabel('Phi (Degrees)')
plt.ylabel('Z (cm)')
cb = plt.colorbar()
cb.set_label('Hits')

plt.subplots_adjust(bottom=0.1, right=0.8, top=2,)
plt.savefig('images/5Det_Comparison_up_NE.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')
p = ax.scatter(Tot[:,4], Tot[:,5], Tot[:,6], c=Tot[:,3], lw=0, s=5, cmap='jet')
ax.set_xlabel('Width (x)')
ax.set_ylabel('Depth (y)')
ax.set_zlabel('Height (z)')
ax.set_xlim3d(-1000,1000)
ax.set_ylim3d(-1000,1000)
ax.set_zlim3d(0,800)
cb=fig.colorbar(p)
cb.set_label('Energy[KeV]')
plt.savefig('images/17Heatmap3D_up_NE.png')
plt.show()

# %%
# intersection function
def isect_line_plane_v3(p0, p1, p_co, p_no, epsilon=1e-6):
    """
    p0, p1: define the line - p0 is last point in air/material and p1 is detector interaction point
    p_co, p_no: define the plane:
        p_co is a point on the plane (plane coordinate).
        p_no is a normal vector defining the plane direction;
             (does not need to be normalized).

    return a Vector or None (when the intersection can't be found).
    """

    u = p0-p1
    dot = np.dot(p_no, u)

    if abs(dot) > epsilon:
        # the factor of the point between p0 -> p1 (0 - 1)
        # if 'fac' is between (0 - 1) the point intersects with the segment.
        # otherwise:
        #  < 0.0: behind p0.
        #  > 1.0: infront of p1.
        w = p0-p_co
        fac = -np.dot(p_no, w) / dot
        u = u*fac
        return p0+u
    else:
        # The segment is parallel to plane
        return None

# %%
#Defining Asphault Surface
p1 = np.array([0, -255, 0]) #Bottom Center Point
p2 = np.array([-255, 255, 0]) #Top Left Point
p3 = np.array([255, 255, 0]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
def inters(surf): #finds where gamma particle departs surface
    intersections = []
    for i in range(len(surf)):
        spoint=np.array([surf[:,4][i], surf[:,5][i], surf[:,6][i]]) #last known point in material
        hpoint=np.array([surf[:,0][i], surf[:,1][i], surf[:,2][i]]) #hit point on detector
        o = isect_line_plane_v3(spoint,hpoint, p1, cp)
        intersections.append(o)
    return intersections

# %%
intersections = inters(Asph)

# %%
gx,gy,gz = map(list,zip(*intersections))
xedges = np.arange(-1000.0, 1000.1, 10.)
yedges = np.arange(-1000.0, 1000.1, 10.)
heatmap5, _, __ = np.histogram2d(gx,gy, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.6))
plt.imshow(heatmap5.T, extent=extent, aspect='auto', origin='lower', cmap='jet')
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Asphalt Scattering - Surface View = ' + str(len(Asph)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Y [cm]')
plt.axis('equal')
plt.grid(True)
plt.savefig('images/10Asphalt_Scattered_Surface_up_NE.png')
plt.show()

# %%
Roof = Tot[(Tot[:,6]>590)] #Creates array of interactions in the Roof - Total Detector Response
North = Tot[(Tot[:,7]<135) & (Tot[:,7]>45) & (Tot[:,6]>0) & (Tot[:,6]<590)] #Creates array of interactions in the North Wall
South = Tot[(Tot[:,7]<-45) & (Tot[:,7]>-135) & (Tot[:,6]>0) & (Tot[:,6]<590)] #Creates array of interactions in the South Wall
East = Tot[(Tot[:,7]<45) & (Tot[:,7]>-45) & (Tot[:,6]>0) & (Tot[:,6]<590)] #Creates array of interactions in the East Wall
West1 = Tot[(Tot[:,7]<-135) & (Tot[:,6]>0) & (Tot[:,6]<590)] #Creates array of interactions in the West Wall 
West2 = Tot[(Tot[:,7]>135) & (Tot[:,6]>0) & (Tot[:,6]<590)] #Creates array of interactions in the West Wall
West = np.vstack((West1,West2))
FullRoof = Tot[(Tot[:,6]>590) & (Tot[:,3]==Full)] #Creates array of interactions in the Roof - Full Energy Deposition
FullNorth = Tot[(Tot[:,7]<135) & (Tot[:,7]>45) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]==Full)] #Creates array of interactions in the North Wall
FullSouth = Tot[(Tot[:,7]<-45) & (Tot[:,7]>-135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]==Full)] #Creates array of interactions in the South Wall
FullEast = Tot[(Tot[:,7]<45) & (Tot[:,7]>-45) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]==Full)] #Creates array of interactions in the East Wall
FullWest1 = Tot[(Tot[:,7]<-135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]==Full)] #Creates array of interactions in the West Wall 
FullWest2 = Tot[(Tot[:,7]>135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]==Full)] #Creates array of interactions in the West Wall
FullWest = np.vstack((FullWest1,FullWest2))
PartRoof = Tot[(Tot[:,6]>590) & (Tot[:,3]<Full)] #Creates array of interactions in the Roof - Partial Energy Deposition
PartNorth = Tot[(Tot[:,7]<135) & (Tot[:,7]>45) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]<Full)] #Creates array of interactions in the North Wall
PartSouth = Tot[(Tot[:,7]<-45) & (Tot[:,7]>-135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]<Full)] #Creates array of interactions in the South Wall
PartEast = Tot[(Tot[:,7]<45) & (Tot[:,7]>-45) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]<Full)] #Creates array of interactions in the East Wall
PartWest1 = Tot[(Tot[:,7]<-135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]<Full)] #Creates array of interactions in the West Wall 
PartWest2 = Tot[(Tot[:,7]>135) & (Tot[:,6]>0) & (Tot[:,6]<590) & (Tot[:,3]<Full)] #Creates array of interactions in the West Wall
PartWest = np.vstack((PartWest1,PartWest2))

# %%
#Defining Roof Surface
p1 = np.array([0, -255, 600]) #Bottom Center Point
p2 = np.array([-255, 255, 600]) #Top Left Point
p3 = np.array([255, 255, 600]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
intersections = inters(Roof)

# %%
rx,ry,rz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(-310.0, 310.1, 10.)
RoofTot, _, __ = np.histogram2d(rx,ry, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.6))
plt.imshow(RoofTot.T, extent=extent, aspect='auto', origin='lower' ,cmap='jet')
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Concrete Scattering - Roof View = ' + str(len(Roof)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Y [cm]')
plt.axis('equal')
plt.axis([-1000, 1000, -1000, 1000])
plt.grid(True)
plt.savefig('images/11Flux_Roof_Total_up_NE.png')
plt.show()

# %%
#Defining North Wall Surface
p1 = np.array([0, 310, 0]) #Bottom Center Point
p2 = np.array([-255, 310, 1000]) #Top Left Point
p3 = np.array([255, 310, 1000]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
intersections = inters(North)

# %%
tnx,tny,tnz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
NorthTot, _, __ = np.histogram2d(tnx,tnz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(NorthTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - North Wall = ' + str(len(North)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/12Flux_North_Total_up_NE.png')
plt.show()

# %%
intersections = inters(FullNorth)

# %%
fnx,fny,fnz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
NorthFull, _, __ = np.histogram2d(fnx,fnz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(NorthFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - North Wall = ' + str(len(FullNorth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/12Flux_North_FullE_up_NE.png')
plt.show()

# %%
intersections = inters(PartNorth)

# %%
pnx,pny,pnz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
NorthPart, _, __ = np.histogram2d(pnx,pnz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(NorthPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - North Wall = ' + str(len(PartNorth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/12Flux_North_PartialE_up_NE.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(20,4.7)) 

plt.subplot(131)
plt.imshow(NorthTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - North Wall = ' + str(len(North)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(132)
plt.imshow(NorthFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - North Wall = ' + str(len(FullNorth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(133)
plt.imshow(NorthPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(NorthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - North Wall = ' + str(len(PartNorth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
plt.savefig('images/12Flux_North_Comparison_up_NE.png')
plt.show()

# %%
#Defining South Wall Surface
p1 = np.array([0, -310, 0]) #Bottom Center Point
p2 = np.array([-255, -310, 1000]) #Top Left Point
p3 = np.array([255, -310, 1000]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
intersections = inters(South)

# %%
tsx,tsy,tsz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
SouthTot, _, __ = np.histogram2d(tsx,tsz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(SouthTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - South Wall = ' + str(len(South)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/13Flux_South_Total_up_NE.png')
plt.show()

# %%
intersections = inters(FullSouth)

# %%
fsx,fsy,fsz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
SouthFull, _, __ = np.histogram2d(fsx,fsz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(SouthFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - South Wall = ' + str(len(FullSouth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/13Flux_South_FullE_up_NE.png')
plt.show()

# %%
intersections = inters(PartSouth)

# %%
psx,psy,psz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
SouthPart, _, __ = np.histogram2d(psx,psz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(SouthPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - South Wall = ' + str(len(PartSouth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/13Flux_South_Partial_up_NE.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(20,4.7)) 

plt.subplot(131)
plt.imshow(SouthTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - South Wall = ' + str(len(South)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(132)
plt.imshow(SouthFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - South Wall = ' + str(len(FullSouth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(133)
plt.imshow(SouthPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(SouthTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - South Wall = ' + str(len(PartSouth)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.savefig('images/13Flux_South_Comparison_up_NE.png')
plt.show()

# %%
#Defining East Wall Surface
p1 = np.array([310, 0, 0]) #Bottom Center Point
p2 = np.array([310, 255, 1000]) #Top Left Point
p3 = np.array([310, -255, 1000]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
intersections = inters(East)

# %%
tex,tey,tez = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
EastTot, _, __ = np.histogram2d(tey,tez, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(EastTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - East Wall = ' + str(len(East)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/14Flux_East_Total_up_NE.png')
plt.show()

# %%
intersections = inters(FullEast)

# %%
fex,fey,fez = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
EastFull, _, __ = np.histogram2d(fey,fez, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(EastFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - East Wall = ' + str(len(FullEast)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/14Flux_East_FullE_up_NE.png')
plt.show()

# %%
intersections = inters(PartEast)

# %%
pex,pey,pez = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
EastPart, _, __ = np.histogram2d(pey,pez, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(EastPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - East Wall = ' + str(len(PartEast)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

#plt.savefig('images/14Flux_East_Partial_up_NE.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(20,4.7)) 

plt.subplot(131)
plt.imshow(EastTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - East Wall = ' + str(len(East)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(132)
plt.imshow(EastFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - East Wall = ' + str(len(FullEast)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(133)
plt.imshow(EastPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(EastTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - East Wall = ' + str(len(PartEast)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.savefig('images/14Flux_East_Comparison_up_NE.png')
plt.show()

# %%
#Defining West Wall Surface
p1 = np.array([-310, 0, 0]) #Bottom Center Point
p2 = np.array([-310, -255, 1000]) #Top Left Point
p3 = np.array([-310, 255, 1000]) #Top Right Point
# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1
# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)

# %%
intersections = inters(West)

# %%
twx,twy,twz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
WestTot, _, __ = np.histogram2d(twy,twz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(WestTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - West Wall = ' + str(len(West)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

#plt.savefig('images/15Flux_West_Total_up_NE.png')
plt.show()

# %%
intersections = inters(FullWest)

# %%
fwx,fwy,fwz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
WestFull, _, __ = np.histogram2d(fwy,fwz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(WestFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - West Wall = ' + str(len(FullWest)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

#plt.savefig('images/15Flux_West_FullE_up_NE.png')
plt.show()

# %%
intersections = inters(PartWest)

# %%
pwx,pwy,pwz = map(list,zip(*intersections))
xedges = np.arange(-310.0, 310.1, 10.)
yedges = np.arange(0.0, 600.1, 10.)
WestPart, _, __ = np.histogram2d(pwy,pwz, bins=[xedges, yedges])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.figure(figsize=(8,6.4))
plt.imshow(WestPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - West Wall = ' + str(len(PartWest)) +' hits')
plt.xlabel('Y [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
#plt.savefig('images/15Flux_West_Partial_up_NE.png')
plt.show()

# %%
plt.clf()
plt.figure(figsize=(20,4.7)) 

plt.subplot(131)
plt.imshow(WestTot.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Total Flux - West Wall = ' + str(len(West)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(132)
plt.imshow(WestFull.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Full Energy Transmission - West Wall = ' + str(len(FullWest)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)

plt.subplot(133)
plt.imshow(WestPart.T, extent=extent, aspect='auto', origin='lower', cmap='jet', vmin=0, vmax=np.max(WestTot))
cb = plt.colorbar()
cb.set_label('Hits')
plt.title('Partial Energy Transmission - West Wall = ' + str(len(PartWest)) +' hits')
plt.xlabel('X [cm]')
plt.ylabel('Z [cm]')
plt.axis('equal')
plt.grid(True)
plt.savefig('images/15Flux_West_Comparison_up.png')
plt.show()

# %%
#fig = plt.figure(figsize=(10,8))
#ax = fig.gca(projection='3d')
#ax.scatter(gx, gy, gz, c=Asph[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#ax.scatter(tnx, tny, tnz, c=North[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#ax.scatter(tsx, tsy, tsz, c=South[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#p=ax.scatter(tex, tey, tez, c=East[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#ax.scatter(twx, twy, twz, c=West[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#ax.scatter(rx, ry, rz, c=Roof[:,3], lw=0, s=5, cmap='jet', vmin=0, vmax=np.max(EastTot))
#ax.set_xlabel('Width (x)')
#ax.set_ylabel('Depth (y)')
#ax.set_zlabel('Height (z)')
#ax.set_xlim3d(-1000,1000)
#ax.set_ylim3d(-1000,1000)
#ax.set_zlim3d(0,1000)
#cb=fig.colorbar(p)
#cb.set_label('Energy[KeV]')
#plt.savefig('images/16Heatmap3D_up.png')
#plt.show()

# %%
#print(WestTot.T.shape)
#np.repeat([np.arange(60)], 62, axis=0)

# %%
# Create mesh for ground.
GX = np.arange(-1000, 1000.1, 10)
GY = np.arange(-1000, 1000.1, 10)
GX, GY = np.meshgrid(GX, GY)

# Create mesh for roof.
RX = np.arange(-310, 310.1, 10)
RY = np.arange(-310, 310.1, 10)
RX, RY = np.meshgrid(RX, RY)

# Create mesh for walls.
VZ = np.arange(0, 600.1, 10)
VY = np.arange(-310, 310.1, 10)
VY, VZ = np.meshgrid(VY, VZ)
HZ = np.arange(0, 600.1, 10)
HX = np.arange(-310, 310.1, 10)
HX, HZ = np.meshgrid(HX, HZ)

# Create flat surfaces.
GZ = np.zeros_like(GX)
RZ = np.zeros_like(RX)
VX = np.zeros_like(VZ) #Vertical Surface
HY = np.zeros_like(HZ) #Horizontal Surface

# Normalize data for colormap use.
A = np.copy(heatmap5.T)
B = np.copy(RoofTot.T)
C = np.copy(EastTot.T)
D = np.copy(WestTot.T)
E = np.copy(NorthTot.T)
F = np.copy(SouthTot.T)

# Normalize data for colormap use to highest
A -= np.min(EastTot.T); A /= np.max(EastTot.T);
B -= np.min(EastTot.T); B /= np.max(EastTot.T);
C -= np.min(EastTot.T); C /= np.max(EastTot.T);
D -= np.min(EastTot.T); D /= np.max(EastTot.T);
E -= np.min(EastTot.T); E /= np.max(EastTot.T);
F -= np.min(EastTot.T); F /= np.max(EastTot.T);

fig = plt.figure(figsize=(15,4.5))
ax = fig.gca(projection='3d')
ax.plot_surface(GX, GY, GZ, facecolors = cm.jet(A))
ax.plot_surface(RX, RY, RZ+600, facecolors = cm.jet(B))
ax.plot_surface(VX+310, VY, VZ, facecolors = cm.jet(C))
ax.plot_surface(VX-310, VY, VZ, facecolors = cm.jet(D))
ax.plot_surface(HX, HY+310, HZ, facecolors = cm.jet(E))
ax.plot_surface(HX, HY-310, HZ, facecolors = cm.jet(F))
ax.set_xlabel('X [cm]')
ax.set_ylabel('Y [cm]')
ax.set_zlabel('Z [cm]')
m = cm.ScalarMappable(cmap=cm.jet)
m.set_array(A)
plt.colorbar(m)


def rotate(angle):
    ax.view_init(60, azim=angle)

print("Making animation")
rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 362, 2), interval=100)
rot_animation.save('rotation.htm', dpi=80, writer='imagemagick')
# Out:
# Making animation
# /Users/darrellstepter/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py:1218: UserWarning: MovieWriter imagemagick unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)
